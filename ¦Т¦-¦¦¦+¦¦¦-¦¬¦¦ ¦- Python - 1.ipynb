# %% [markdown]
# Уильям Эдвард Деминг:
# > Мы верим только Богу, а все остальные должны приносить данные.

# %%
# Заголовки
import numpy as np
import pandas as pd

print('numpy:',  np.__version__)
print('pandas:',  pd.__version__)
# Out:
# numpy: 1.13.3
# pandas: 0.20.3

# %%
# Загрузка данных
pd.read_csv('data/iris.csv', header=None)
#df = pd.read_csv('data/iris.csv')
#df
# Out:
#                 0            1             2            3          4
# 0    sepal_length  sepal_width  petal_length  petal_width    species
# 1             5.1          3.5           1.4          0.2     setosa
# 2             4.9            3           1.4          0.2     setosa
# 3             4.7          3.2           1.3          0.2     setosa
# 4             4.6          3.1           1.5          0.2     setosa
# 5               5          3.6           1.4          0.2     setosa
# 6             5.4          3.9           1.7          0.4     setosa
# 7             4.6          3.4           1.4          0.3     setosa
# 8               5          3.4           1.5          0.2     setosa
# 9             4.4          2.9           1.4          0.2     setosa
# 10            4.9          3.1           1.5          0.1     setosa
# 11            5.4          3.7           1.5          0.2     setosa
# 12            4.8          3.4           1.6          0.2     setosa
# 13            4.8            3           1.4          0.1     setosa
# 14            4.3            3           1.1          0.1     setosa
# 15            5.8            4           1.2          0.2     setosa
# 16            5.7          4.4           1.5          0.4     setosa
# 17            5.4          3.9           1.3          0.4     setosa
# 18            5.1          3.5           1.4          0.3     setosa
# 19            5.7          3.8           1.7          0.3     setosa
# 20            5.1          3.8           1.5          0.3     setosa
# 21            5.4          3.4           1.7          0.2     setosa
# 22            5.1          3.7           1.5          0.4     setosa
# 23            4.6          3.6             1          0.2     setosa
# 24            5.1          3.3           1.7          0.5     setosa
# 25            4.8          3.4           1.9          0.2     setosa
# 26              5            3           1.6          0.2     setosa
# 27              5          3.4           1.6          0.4     setosa
# 28            5.2          3.5           1.5          0.2     setosa
# 29            5.2          3.4           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 121           6.9          3.2           5.7          2.3  virginica
# 122           5.6          2.8           4.9            2  virginica
# 123           7.7          2.8           6.7            2  virginica
# 124           6.3          2.7           4.9          1.8  virginica
# 125           6.7          3.3           5.7          2.1  virginica
# 126           7.2          3.2             6          1.8  virginica
# 127           6.2          2.8           4.8          1.8  virginica
# 128           6.1            3           4.9          1.8  virginica
# 129           6.4          2.8           5.6          2.1  virginica
# 130           7.2            3           5.8          1.6  virginica
# 131           7.4          2.8           6.1          1.9  virginica
# 132           7.9          3.8           6.4            2  virginica
# 133           6.4          2.8           5.6          2.2  virginica
# 134           6.3          2.8           5.1          1.5  virginica
# 135           6.1          2.6           5.6          1.4  virginica
# 136           7.7            3           6.1          2.3  virginica
# 137           6.3          3.4           5.6          2.4  virginica
# 138           6.4          3.1           5.5          1.8  virginica
# 139             6            3           4.8          1.8  virginica
# 140           6.9          3.1           5.4          2.1  virginica
# 141           6.7          3.1           5.6          2.4  virginica
# 142           6.9          3.1           5.1          2.3  virginica
# 143           5.8          2.7           5.1          1.9  virginica
# 144           6.8          3.2           5.9          2.3  virginica
# 145           6.7          3.3           5.7          2.5  virginica
# 146           6.7            3           5.2          2.3  virginica
# 147           6.3          2.5             5          1.9  virginica
# 148           6.5            3           5.2            2  virginica
# 149           6.2          3.4           5.4          2.3  virginica
# 150           5.9            3           5.1          1.8  virginica
#
# [151 rows x 5 columns]

# %%
# Размерность данных
#df.shape
#rint (df)
#rint ('shape = ', df.shape)
#shape = {0}'.format(df.shape)

# %%
# Просмотр данных
df.head()
#df.tail(10)
#df['sepal_length'].head()
#df.sepal_length.head()
#df.sepal_length[5:15]
#df[['sepal_length', 'petal_width']].head(10)
#print(df.head(5))
#print(df.loc[5:7])
#print(df.loc[0]['sepal_length'])
#print(df[0:3])
#print(df.loc[0, ['sepal_length', 'petal_width']])
#print(df.loc[0:5, ['sepal_length', 'petal_width']])
#print(df.loc[0:5:2, ['sepal_length', 'petal_width']])
#df.at[5, 'sepal_length']
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
#Переименование столбцов
#df.head()
#df.columns = ['sepal_length1', 'sepal_width1', 'petal_length1', 'petal_width1','species1']
#df.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width','species']
#---v
#df_copy = df.rename(columns={'species':'species!'})
#print(df.head())
#print(df_copy.head())
#---^

# %%
# Типы данных
#df.dtypes
#df['sepal_length'].dtype
#df['sepal_length'] = df['sepal_length'].astype('float32');
#df['sepal_length'].dtype
#type(df)
#type(df.sepal_length)
#type(df.loc[0])

# %%
# Индекс
#df.head()
#df.index = df['petal_width']
#df.index = range(len(df.index))

# %%
# Копирование данных
df_copy = df.copy()
df_copy.loc[0, 'sepal_length'] = 1115
print(df.loc[0:1])
print(df_copy[0:2])
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
#    sepal_length  sepal_width  petal_length  petal_width species
# 0        1115.0          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
# Добавление и удаление столбцов
#df.head()
#df.shape
#---v
#df_column = df['species']
#del df['species']
#df.head()
#---^
#df.shape
#df_column
#df['new_species'] = df_column
#---v
#df['sepal_length_doubled'] = df['sepal_length'] * 2
#df.head()
#---^
#---v
new_col = df['sepal_length'] * 2
df.insert(0,'sepal_length_doubled2', new_col)
df.head()
#---^
# Out:
#    sepal_length_doubled2  sepal_length  sepal_width  petal_length  \
# 0                   10.2           5.1          3.5           1.4
# 1                    9.8           4.9          3.0           1.4
# 2                    9.4           4.7          3.2           1.3
# 3                    9.2           4.6          3.1           1.5
# 4                   10.0           5.0          3.6           1.4
#
#    petal_width new_species  sepal_length_doubled
# 0          0.2      setosa                  10.2
# 1          0.2      setosa                   9.8
# 2          0.2      setosa                   9.4
# 3          0.2      setosa                   9.2
# 4          0.2      setosa                  10.0

# %%
# Фильтрация
df.new_species == 'setosa'
#print(df[df.new_species == 'setosa'].shape)
#print(df[df.sepal_length > 5].shape)
#print(df[(df.new_species == 'setosa') & (df.sepal_length > 5) ].shape)
#print(df[(df.new_species == 'setosa') | (df.sepal_length > 5) ].shape)
#print(df[(df.new_species == 'setosa') | (df.sepal_length > 5) ]['sepal_length'])
#print(df[(df.new_species == 'setosa') | (df.sepal_length > 5) ][['sepal_length', 'sepal_width']])
# Out:
# (22, 7)

# %%
# Добавление и удаление строк
#---v
#df_1 = df.head()
#df_2 = df.tail()
#df_3 = df_1.append(df_2)
#df_4 = df_1.append(df_2, ignore_index=True)
#print(df_3)
#print(df_4)
#---^
#---v
#df_1 = df.head()
#df_2 = df_1.drop([1,2,3])
#print(df_1)
#print(df_2)
#---^
#---v
#df_1 = df.head()
#df_2 = df_1.drop(np.arange(1, 4))
#print(df_1)
#print(df_2)
#---^
#df.sepal_length > 7
#df[df.sepal_length > 7]
#df[df.sepal_length > 7].shape
#~(df.sepal_length > 7)
#df[~(df.sepal_length > 7)]
#df[~(df.sepal_length > 7)].shape
# Out:
# (138, 7)
